# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If you rearrange the letters "L A S T I N G" to form a new word, then remove the first and last letters of that new word, and finally reverse the remaining letters, what is the resulting word?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# We start with the letters: **L A S T I N G**
#
# Step 1: Rearrange the letters to form a new word.
#
# Let's see what words can be formed from these letters:
#
# - "LASTING" itself is a valid English word.
# - Let's check if using "LASTING" makes sense, since it's the original order.
#
# Step 2: Remove the first and last letters of that new word.
#
# If the word is **LASTING**:
#
# - First letter: L
# - Last letter: G
# - Removing those leaves: **ASTIN**
#
# Step 3: Reverse the remaining letters.
#
# Reverse "ASTIN" = **NITSA**
#
# "NITSA" is not an English word, but the problem doesn't say it has to be.
#
# Is there another arrangement that makes a better result?
#
# Try the word "SALTING":
#
# - First letter: S
# - Last letter: G
# - Remove first and last: **ALTI N** (letters A L T I N)
#
# Reverse: **NITLA**
#
# Not a word.
#
# Try "STALING":
#
# - First: S
# - Last: G
# - Remove first and last: **TALI N**
#
# Reverse: **NILAT**
#
# No.
#
# Try "TALINGS": (plural of taling? less common)
#
# - Remove first (T) and last (S): **ALING**
# - Reverse: **GNILA**
#
# No.
#
# Try "ALSTING":
#
# - Not a standard English word.
#
# What about "SILTING"?
#
# - Letters: S I L T I N G
#
# Our letters are L A S T I N G, so one S only, so SILTING is not possible (we got only one S).
#
# Check if "STINGAL" or "TINGALS":
#
# - Not really common words.
#
# Try "GASTLIN":
#
# - Not standard.
#
# Let's try "NITGLAS":
#
# - No.
#
# Now, look for notable word: "LASTING"
#
# When reversed after deleting first and last letters, got "NITSA"
#
# Is "NITSA" meaningful?
#
# Maybe the question expects the answer "NITSA".
#
# Alternatively, maybe the rearranged word is "SALTING"
#
# Check "SALTING":
#
# - Remove first (S) and last (G) letters: ALTIN
#
# Reverse: NITLA
#
# No.
#
# Another approach:
#
# Rearrange letters to form "STALING"
#
# - Remove S and G: TALI N
#
# Reverse: NILAT
#
# No.
#
# Alternatively, what if the rearranged word is "INGLATS" (not an English word), or "TAILSNG" (no).
#
# Maybe the rearranged word is "SATINGL"?
#
# No.
#
# Or "SLATING"?
#
# "SLATING" is a valid English word meaning covering with slate.
#
# Check "SLATING"
#
# Remove first and last letters: first=S, last=G
#
# Remaining: LATIN
#
# Reverse "LATIN" = "NITAL"
#
# "NITAL" is not a common English word, but "Nital" is a real word - it's a chemical solution used in metallurgy.
#
# Maybe the problem aims at "LATIN" reversed to "NITAL".
#
# Is "NITAL" acceptable? It's a proper noun and technical term.
#
# So the resulting word would be "NITAL" from this.
#
# So:
#
# 1. Rearranged word: SLATING
#
# 2. Remove first and last letters: LATIN
#
# 3. Reverse: NITAL
#
# Hence, the resulting word is **NITAL**.
#
# # Final answer:
#
# **NITAL**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# We start with the letters: **L A S T I N G**
#
# Step 1: Rearrange the letters to form a new word.
#
# Let's see what words can be formed from these letters:
#
# - "LASTING" itself is a valid English word.
# - Let's check if using "LASTING" makes sense, since it's the original order.
#
# Step 2: Remove the first and last letters of that new word.
#
# If the word is **LASTING**:
#
# - First letter: L
# - Last letter: G
# - Removing those leaves: **ASTIN**
#
# Step 3: Reverse the remaining letters.
#
# Reverse "ASTIN" = **NITSA**
#
# "NITSA" is not an English word, but the problem doesn't say it has to be.
#
# Is there another arrangement that makes a better result?
#
# Try the word "SALTING":
#
# - First letter: S
# - Last letter: G
# - Remove first and last: **ALTI N** (letters A L T I N)
#
# Reverse: **NITLA**
#
# Not a word.
#
# Try "STALING":
#
# - First: S
# - Last: G
# - Remove first and last: **TALI N**
#
# Reverse: **NILAT**
#
# No.
#
# Try "TALINGS": (plural of taling? less common)
#
# - Remove first (T) and last (S): **ALING**
# - Reverse: **GNILA**
#
# No.
#
# Try "ALSTING":
#
# - Not a standard English word.
#
# What about "SILTING"?
#
# - Letters: S I L T I N G
#
# Our letters are L A S T I N G, so one S only, so SILTING is not possible (we got only one S).
#
# Check if "STINGAL" or "TINGALS":
#
# - Not really common words.
#
# Try "GASTLIN":
#
# - Not standard.
#
# Let's try "NITGLAS":
#
# - No.
#
# Now, look for notable word: "LASTING"
#
# When reversed after deleting first and last letters, got "NITSA"
#
# Is "NITSA" meaningful?
#
# Maybe the question expects the answer "NITSA".
#
# Alternatively, maybe the rearranged word is "SALTING"
#
# Check "SALTING":
#
# - Remove first (S) and last (G) letters: ALTIN
#
# Reverse: NITLA
#
# No.
#
# Another approach:
#
# Rearrange letters to form "STALING"
#
# - Remove S and G: TALI N
#
# Reverse: NILAT
#
# No.
#
# Alternatively, what if the rearranged word is "INGLATS" (not an English word), or "TAILSNG" (no).
#
# Maybe the rearranged word is "SATINGL"?
#
# No.
#
# Or "SLATING"?
#
# "SLATING" is a valid English word meaning covering with slate.
#
# Check "SLATING"
#
# Remove first and last letters: first=S, last=G
#
# Remaining: LATIN
#
# Reverse "LATIN" = "NITAL"
#
# "NITAL" is not a common English word, but "Nital" is a real word - it's a chemical solution used in metallurgy.
#
# Maybe the problem aims at "LATIN" reversed to "NITAL".
#
# Is "NITAL" acceptable? It's a proper noun and technical term.
#
# So the resulting word would be "NITAL" from this.
#
# So:
#
# 1. Rearranged word: SLATING
#
# 2. Remove first and last letters: LATIN
#
# 3. Reverse: NITAL
#
# Hence, the resulting word is **NITAL**.
#
# # Final answer:
#
# **NITAL**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Can you help me identify the most promising business areas with applications for agentic AI and the exact problems / pain ponts agentic models would solve (and how)?"}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message

# %%
display(Markdown(business_idea))
# Out:
# Certainly! Agentic AI refers to AI systems capable of acting autonomously and proactively to achieve goals, often interacting with environments and users with a degree of initiative. These systems go beyond reactive or assistive AI by planning, decision-making, and adapting dynamically.
#
# Here are some of the most promising business areas for agentic AI applications, along with specific problems or pain points they address and how agentic AI can solve them:
#
# ---
#
# ### 1. **Supply Chain Management & Logistics**
#
# **Pain Points:**
# - Complex coordination among suppliers, manufacturers, distributors.
# - Demand forecasting inaccuracies leading to overstocking or stockouts.
# - Inefficient route planning increasing costs and delivery times.
# - Lack of real-time adaptability to disruptions (e.g., delays, weather).
#
# **Agentic AI Solutions:**
# - Autonomous agents monitor supply chain data in real-time, predict disruptions, and dynamically reroute shipments.
# - Proactive inventory management through continuous demand forecasting and adjusting orders automatically.
# - Coordination agents negotiate tasks and resources among different stakeholders, optimizing workflows end-to-end.
# - Adaptive planning agents simulate scenarios and autonomously initiate contingency measures.
#
# ---
#
# ### 2. **Customer Service & Support**
#
# **Pain Points:**
# - High volume of routine inquiries overwhelming human agents.
# - Inconsistent service quality and slow response times.
# - Difficulty in resolving complex multi-step problems.
# - Lack of personalized interactions based on customer history and context.
#
# **Agentic AI Solutions:**
# - Autonomous conversational agents that understand customer intent, escalate when needed, and proactively follow up.
# - Self-service systems that autonomously troubleshoot issues or guide users through complex procedures without human intervention.
# - Agents that monitor customer satisfaction in real-time and initiate personalized outreach.
# - Dynamic learning from prior interactions to improve future responses and anticipate customer needs.
#
# ---
#
# ### 3. **Finance & Investment Management**
#
# **Pain Points:**
# - Rapidly changing market conditions requiring timely decisions.
# - Large-scale data analysis and portfolio optimization beyond human capabilities.
# - Fraud detection requiring proactive monitoring.
# - Compliance complexity and risk management.
#
# **Agentic AI Solutions:**
# - Autonomous trading agents that adapt strategies dynamically based on market data.
# - Risk assessment agents that scan multiple signals and initiate protective actions or compliance checks.
# - Fraud detection agents that proactively monitor transactions and initiate investigations.
# - Robo-advisors providing personalized financial planning, adjusting portfolios in real-time.
#
# ---
#
# ### 4. **Healthcare & Personalized Medicine**
#
# **Pain Points:**
# - Diagnosing and treating complex or rare conditions requires expert knowledge and integration of diverse data.
# - Managing chronic conditions requires continuous monitoring and adjustment.
# - Scheduling and resource allocation inefficiencies in hospitals.
# - Patient adherence to treatments and lifestyle changes.
#
# **Agentic AI Solutions:**
# - Diagnostic agents synthesizing patient data and medical literature to suggest tests, treatments, or referrals.
# - Virtual health assistants that monitor vitals continuously, detect anomalies, and recommend interventions.
# - Scheduling agents autonomously optimize resources, patient flow, and staff shifts.
# - Personalized coaching agents that proactively engage patients to improve adherence.
#
# ---
#
# ### 5. **Manufacturing & Industry 4.0**
#
# **Pain Points:**
# - Equipment downtime leading to production losses.
# - Quality control requiring constant monitoring.
# - Complex multi-device coordination for flexible manufacturing.
# - Energy inefficiencies and waste.
#
# **Agentic AI Solutions:**
# - Predictive maintenance agents that autonomously schedule repairs before breakdowns occur.
# - Quality agents that monitor sensor data and adjust processes to maintain standards.
# - Coordination agents managing robotic systems and supply inputs for adaptive production lines.
# - Energy optimization agents minimizing waste based on real-time consumption data.
#
# ---
#
# ### 6. **Retail & E-commerce**
#
# **Pain Points:**
# - Personalized marketing and customer engagement at scale.
# - Inventory management with fast-changing demand patterns.
# - Fraud and counterfeit detection.
# - Efficient and flexible supply chains.
#
# **Agentic AI Solutions:**
# - Autonomous marketing agents that design and send personalized campaigns, optimizing timing and content.
# - Demand forecasting agents adjusting stock levels and pricing dynamically.
# - Fraud detection agents analyzing patterns and initiating security protocols.
# - Agents optimizing order fulfillment routes and supplier negotiations.
#
# ---
#
# ### 7. **Real Estate & Property Management**
#
# **Pain Points:**
# - Tenant management and maintenance requests.
# - Dynamic pricing of rentals or sales.
# - Market analysis and investment decisions.
# - Energy management and sustainability in buildings.
#
# **Agentic AI Solutions:**
# - Virtual property managers autonomously responding to tenant issues and coordinating maintenance.
# - Pricing agents adjusting rents based on market trends and occupancy.
# - Investment agents scanning markets and suggesting purchases or sales.
# - Energy agents optimizing HVAC and lighting for efficiency.
#
# ---
#
# ### How Agentic AI Solves These Problems
#
# - **Autonomy:** Agents can act without constant human instruction, reducing operational overhead.
# - **Proactivity:** Instead of waiting for problems, agents anticipate and prevent them.
# - **Continuous Learning:** Agents improve over time by learning from data and interaction outcomes.
# - **Coordination:** Multiple agents can collaborate, negotiating and optimizing complex workflows.
# - **Customization & Personalization:** Tailoring actions to individual user preferences and contexts.
#
# ---
#
# ### Summary
#
# Agentic AI is particularly valuable in areas where:
#
# - Complex, dynamic environments require adaptable, real-time decision-making.
# - Tasks involve coordination across multiple actors or systems.
# - Proactive problem prevention and opportunity identification are critical.
# - Scalability of personalized or context-aware interaction improves business value.
#
# If you want, I can also provide examples of companies pioneering agentic AI in these fields or deeper technical insight into agent architectures that make these applications possible. Would you like me to do that?
